# %%
from amumbo_strat_helper import get_vix_data, get_sp500_data, check_signals, plot_scraped_data
# Parameters
VIX_THRESHOLD = 28  # Define high volatility as VIX > 28
SMA_PERIOD = 50     # For quarter 200 moving average

# Get data
vix_data = get_vix_data()
sp500_data = get_sp500_data()

vix_data.columns, sp500_data.columns, vix_data.shape, sp500_data.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  (504, 6),
#  (503, 6))

# %%
# Check signals
check_signals(sp500_data, vix_data, VIX_THRESHOLD, SMA_PERIOD)
# Out:
# Latest VIX:                20.3300
# Latest S&P 500 Price:    5808.1201
# Latest SMA50 Diff:        125.4421
# Latest SMA Quarter Diff:  220.4431
# Latest SMA150 Diff:       366.1741
# Latest S&P 500 SMA200:   5333.8762
#
# Market conditions are stable. No immediate action needed.

# %%
# Plot the scraped data
plot_scraped_data(sp500_data, vix_data, VIX_THRESHOLD, SMA_PERIOD)
