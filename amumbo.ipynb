# %%
from amumbo_strat_helper import get_vix_data, get_sp500_data, get_amumbo_data, check_signals, plot_scraped_data
# Parameters
VIX_THRESHOLD = 28  # Define high volatility as VIX > 28
SMA_PERIOD = 50     # For quarter 200 moving average

# Get data
vix_data = get_vix_data()
sp500_data = get_sp500_data()
amumbo_data = get_amumbo_data()

vix_data.columns, sp500_data.columns, amumbo_data.columns, vix_data.shape, sp500_data.shape, amumbo_data.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  (504, 6),
#  (504, 6),
#  (514, 6))

# %%
# Check signals
check_signals(sp500_data, amumbo_data, vix_data, VIX_THRESHOLD, SMA_PERIOD)
# Out:
# Latest VIX:                          16.4400
#
# Latest VIX M75 Week Diff:            11.6050
# Latest VIX M75 Month Diff:           11.6050
# -----------------------------------------
# Latest S&P 500 Price:              5903.3901
# Latest S&P 500 SMA200:             5429.9008
#
# Latest S&P 500 SMA50 Diff:          101.0940
# Latest S&P 500 SMA Quarter Diff:    242.0232
# Latest S&P 500 SMA150 Diff:         369.6263
# -----------------------------------------
# -----------------------------------------
# Latest Amumbo Price:                 24.4300
# Latest Amumbo SMA200:                19.6574
#
# Latest Amumbo SMA50 Diff:             2.4156
# Latest Amumbo SMA Quarter Diff:       3.6017
# Latest Amumbo SMA150 Diff:            4.1642
#
#
# Market conditions are stable. No immediate action needed.

# %%
# Plot the S&P 500 Analysis
plot_scraped_data(sp500_data, vix_data, VIX_THRESHOLD, SMA_PERIOD, 'S&P 500')

# %%
# Plot the Amumbo Analysis
plot_scraped_data(amumbo_data, vix_data, VIX_THRESHOLD, SMA_PERIOD, 'Amumbo')
