# %%
from lvdx_strat_helper import get_dax_data, get_lvdx_data, check_signals, plot_scraped_data
# Parameters
SMA_PERIOD = 50     # For quarter 200 moving average

# Get data
dax_data = get_dax_data()
lvdx_data = get_lvdx_data()

dax_data.columns, lvdx_data.columns, dax_data.shape, lvdx_data.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  (514, 6),
#  (514, 6))

# %%
# Check signals
check_signals(dax_data, lvdx_data, SMA_PERIOD)
# Out:
# Latest DAX Price:                  19626.4492
# Latest DAX SMA200:                 18510.2897
#
# Latest DAX SMA50 Diff:               356.8965
# Latest DAX SMA Quarter Diff:         775.6419
# Latest DAX SMA150 Diff:              926.3051
# ---------------------------------------------
# ---------------------------------------------
# Latest LVDX.DE Price:                 16.0920
# Latest LVDX.DE SMA200:                14.6427
#
# Latest LVDX.DE SMA50 Diff:             0.5456
# Latest LVDX.DE SMA Quarter Diff:       1.1295
# Latest LVDX.DE SMA150 Diff:            1.2602
#
#
# Market conditions are stable. No immediate action needed.

# %%
# Plot the DAX Analysis
plot_scraped_data(dax_data, SMA_PERIOD, ticker_name='DAX')

# %%
# Plot LevDAX daily ETF Analysis 
plot_scraped_data(lvdx_data, SMA_PERIOD, ticker_name='LevDAX')
