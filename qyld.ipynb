# %%
from qyld_strat_helper import get_vnx_data, get_nasdaq100_data, get_qyld_data, check_signals, plot_scraped_data
# Parameters
VNX_THRESHOLD = 33  # Define high volatility as VIX > 33
SMA_PERIOD = 50     # For quarter 200 moving average

# Get data
vnx_data = get_vnx_data()
ndx100_data = get_nasdaq100_data()
qyld_data = get_qyld_data()

vnx_data.columns, ndx100_data.columns, qyld_data.columns, vnx_data.shape, ndx100_data.shape, qyld_data.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  (502, 6),
#  (503, 6),
#  (503, 6))

# %%
# Check signals
check_signals(ndx100_data, qyld_data, vnx_data, VNX_THRESHOLD, SMA_PERIOD)
# Out:
# Latest VNX:                              16.0700
#
# Latest VNX M75 Week Diff:                13.6100
# Latest VNX M75 Month Diff:               13.6100
# -----------------------------------------------
# Latest Nasdaq 100 Price:              20930.3691
# Latest Nasdaq 100 SMA200:             19137.9632
#
# Latest Nasdaq 100 SMA50 Diff:           565.3388
# Latest Nasdaq 100 SMA Quarter Diff:    1141.3667
# Latest Nasdaq 100 SMA150 Diff:         1392.7201
# -----------------------------------------------
# -----------------------------------------------
# Latest QYLD Price:                       18.2200
# Latest QYLD SMA200:                      17.7998
#
# Latest QYLD SMA50 Diff:                   0.0588
# Latest QYLD SMA Quarter Diff:             0.3526
# Latest QYLD SMA150 Diff:                  0.4193
#
#
# Market conditions are stable. No immediate action needed.

# %%
# Plot the Nasdaq 100 Analysis
plot_scraped_data(ndx100_data, vnx_data, VNX_THRESHOLD, SMA_PERIOD, 'Nasdaq 100')

# %%
# Plot the QYLD Analysis
plot_scraped_data(qyld_data, vnx_data, VNX_THRESHOLD, SMA_PERIOD, 'QYLD')
