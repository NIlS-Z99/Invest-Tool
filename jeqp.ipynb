# %%
from jeqp_strat_helper import get_vxn_data, get_nasdaq100_data, get_jeqp_data, check_signals, plot_scraped_data
# Parameters
VXN_THRESHOLD = 33  # Define high volatility as VIX > 33
SMA_PERIOD = 50     # For quarter 200 moving average

# Get data
vxn_data = get_vxn_data()
ndx100_data = get_nasdaq100_data()
jeqp_data = get_jeqp_data()

vxn_data.columns, ndx100_data.columns, jeqp_data.columns, vxn_data.shape, ndx100_data.shape, jeqp_data.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object'),
#  (502, 6),
#  (503, 6),
#  (25, 6))

# %%
# Check signals
check_signals(ndx100_data, jeqp_data, vxn_data, VXN_THRESHOLD, SMA_PERIOD)
# Out:
# Latest VXN:                              15.1500
#
# Latest VXN M75 Week Diff:                16.9050
# Latest VXN M75 Month Diff:               16.9050
# ------------------------------------------------
# Latest Nasdaq 100 Price:              21622.2500
# Latest Nasdaq 100 SMA200:             19229.8249
#
# Latest Nasdaq 100 SMA50 Diff:          1112.0782
# Latest Nasdaq 100 SMA Quarter Diff:    1711.1466
# Latest Nasdaq 100 SMA150 Diff:         1958.2046
# ------------------------------------------------
# ------------------------------------------------
# Latest JEQP Price:                       24.9550
# Latest JEQP SMA200:                          nan
#
# Latest JEQP SMA50 Diff:                      nan
# Latest JEQP SMA Quarter Diff:                nan
# Latest JEQP SMA150 Diff:                     nan
#
#
# Market conditions are stable. No immediate action needed.

# %%
# Plot the Nasdaq 100 Analysis
plot_scraped_data(ndx100_data, vxn_data, VXN_THRESHOLD, SMA_PERIOD, 'Nasdaq 100')

# %%
# Plot the QYLD Analysis
plot_scraped_data(jeqp_data, vxn_data, VXN_THRESHOLD, SMA_PERIOD, 'JEQP')
